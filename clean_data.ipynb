# %%
import pandas as pd

happiness_df = pd.read_parquet("happiness_rank_score_by_country_2022.parquet").drop([146])
happiness_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  146 non-null    object
#  1   rank     146 non-null    int64
#  2   score    146 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 3.5+ KB

# %%
countries_and_capitals_localization_html = "http://techslides.com/list-of-countries-and-capitals"
countries_and_capitals_localization = pd.read_html(countries_and_capitals_localization_html, header=0)[0]

not_included = [
    ["Ivory Coast", "Yamoussoukro", "6.8205500", "-5.2767400", "CI", "Africa"],
    ["Eswatini", "Mbabane", "-26.31667", "31.13333", "SZ", "Africa"],
    ["North Macedonia", "Skopje", "41.99646", "21.43141", "MK", "Europe"]
               ]
columns = ["Country Name", "Capital Name", "Capital Latitude", "Capital Longitude", "Country Code", "Continent Name"]
not_included = pd.DataFrame(not_included, columns=columns)
countries_and_capitals_localization = pd.concat([countries_and_capitals_localization, not_included]).sort_values("Country Name")

countries_and_capitals_localization.rename(columns={
    "Country Name": "country",
    "Capital Name": "capital",
    "Capital Latitude": "capital_latitude",
    "Capital Longitude": "capital_longitude",
    "Country Code": "country_code",
    "Continent Name": "continent",
    }, inplace=True
)
countries_and_capitals_localization.tail()
# Out:
#                country    capital capital_latitude capital_longitude  \
# 240  Wallis and Futuna   Mata-Utu           -13.95       -171.933333
# 241     Western Sahara  El-AaiÃºn        27.153611        -13.203333
# 242              Yemen      Sanaa            15.35              44.2
# 243             Zambia     Lusaka       -15.416667         28.283333
# 244           Zimbabwe     Harare       -17.816667         31.033333
#
#     country_code  continent
# 240           WF  Australia
# 241           EH     Africa
# 242           YE       Asia
# 243           ZM     Africa
# 244           ZW     Africa

# %%
countries_and_capitals_localization["country"].tolist()
# Out:
# ['Afghanistan',
#  'Aland Islands',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antarctica',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Indian Ocean Territory',
#  'British Virgin Islands',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cape Verde',
#  'Cayman Islands',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Christmas Island',
#  'Cocos Islands',
#  'Colombia',
#  'Comoros',
#  'Cook Islands',
#  'Costa Rica',
#  'Cote d’Ivoire',
#  'Croatia',
#  'Cuba',
#  'CuraÃ§ao',
#  'Cyprus',
#  'Czech Republic',
#  'Democratic Republic of the Congo',
# ...

# %%
countries_and_capitals_localization.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 248 entries, 0 to 244
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country            248 non-null    object
#  1   capital            244 non-null    object
#  2   capital_latitude   248 non-null    object
#  3   capital_longitude  248 non-null    object
#  4   country_code       245 non-null    object
#  5   continent          248 non-null    object
# dtypes: object(6)
# memory usage: 13.6+ KB

# %%
happiness_df["country"].replace({
    "Czechia": "Czech Republic",
    "Taiwan Province of China": "Taiwan",
    "North Cyprus": "Cyprus",
    "Hong Kong S.A.R. of China": "Hong Kong",
    "Gambia": "The Gambia",
    "Congo": "Democratic Republic of the Congo",
    "Palestinian Territories": "Palestine",
    "Eswatini, Kingdom of": "Eswatini",
}, inplace=True)

# %%
happiness_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  146 non-null    object
#  1   rank     146 non-null    int64
#  2   score    146 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 3.5+ KB

# %%
countries_and_capitals_localization.head()
# Out:
#           country    capital capital_latitude capital_longitude country_code  \
# 0     Afghanistan      Kabul        34.516667         69.183333           AF
# 1   Aland Islands  Mariehamn        60.116667              19.9           AX
# 2         Albania     Tirana        41.316667         19.816667           AL
# 3         Algeria    Algiers            36.75              3.05           DZ
# 4  American Samoa  Pago Pago       -14.266667            -170.7           AS
#
#    continent
# 0       Asia
# 1     Europe
# 2     Europe
# 3     Africa
# 4  Australia

# %%
countries_and_capitals_localization["continent"] = countries_and_capitals_localization["continent"].astype("category")
countries_and_capitals_localization["capital_latitude"] = countries_and_capitals_localization["capital_latitude"].astype("float")
countries_and_capitals_localization["capital_longitude"] = countries_and_capitals_localization["capital_longitude"].astype("float")

# %%
countries_and_capitals_localization.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 248 entries, 0 to 244
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country            248 non-null    object
#  1   capital            244 non-null    object
#  2   capital_latitude   248 non-null    float64
#  3   capital_longitude  248 non-null    float64
#  4   country_code       245 non-null    object
#  5   continent          248 non-null    category
# dtypes: category(1), float64(2), object(3)
# memory usage: 12.2+ KB

# %%
happiness_df.to_parquet("happiness_rank_score_by_country_2022.parquet")

# %%
countries_and_capitals_localization.to_parquet("country_code_capital_location_continent.parquet")

# %%
pd.read_parquet("country_code_capital_location_continent.parquet")["country"]
# Out:
# Traceback (most recent call last):
#
#   File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3398 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [29] in <cell line: 1>
#     pd.read_parquet("country_code_capital_location_continent.parquet").query("country = United States")
#
#   File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4111 in query
#     res = self.eval(expr, **kwargs)
#
#   File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4240 in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File ~/.local/lib/python3.10/site-packages/pandas/core/computation/eval.py:350 in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File ~/.local/lib/python3.10/site-packages/pandas/core/computation/expr.py:811 in __init__
#     self.terms = self.parse()
#
#   File ~/.local/lib/python3.10/site-packages/pandas/core/computation/expr.py:830 in parse
# ...
